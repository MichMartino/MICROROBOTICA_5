# %% [markdown]
# # Questo è il titolo del primo notebook
# ## Questo è un sottotitolo
#
# I notebook *jupyter* sono uno strumento di sviluppo per la **data-science** e l'**IA**
#
# Un notebook può contenere:
# * codice Python eseguibile
# * testo formattato
# * immagini
# * equazioni

# %%
a = 1

# %%
print(a)
# Out:
# 1

# %%
8234*245
# Out:
# 2017330
