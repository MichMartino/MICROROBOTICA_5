# %%
def mediaStudente(studenti):
    return

# %%
def migliorStudenteMateria():
    pass

# %%
def studentiMediaSopraSoglia():
    pass

# %%
studenti = {
"Mario": [("Matematica", 8.5), ("Fisica", 7.0), ("Chimica", 9.0)],
"Anna": [("Matematica", 9.5), ("Fisica", 8.5), ("Storia", 8.0)],
"Luca": [("Matematica", 7.0), ("Chimica", 7.5), ("Storia", 9.5)]
}

mediaStudente(studenti)
# Out:
# ["[('Matematica', 8.5), ('Fisica', 7.0), ('Chimica', 9.0)]", "[('Matematica', 9.5), ('Fisica', 8.5), ('Storia', 8.0)]", "[('Matematica', 7.0), ('Chimica', 7.5), ('Storia', 9.5)]"]
