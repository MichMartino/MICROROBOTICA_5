# %%
#Seme per algoritmo di generazione, è un numero di partenza da cui parte l'algoritmo

# %%
import numpy as np

# %%
np.random.seed(42) #Genera sempre gli stessi numeri, esempio di seed: PID (Numero processo), oppure accelerometro telefono...clock da gennaio..
numeri = np.random.randint(1, 20, 3) #19 compreso
numeri
# Out:
# array([ 7, 15, 11], dtype=int32)
