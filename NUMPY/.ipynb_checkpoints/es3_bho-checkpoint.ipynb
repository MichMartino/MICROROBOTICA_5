# %%
import numpy as np

# %%
# %%timeit #per calcolare quanto ci mette
SIZE = (4, 6)
P = 5
array = np.zeros(SIZE[0] * SIZE[1], dtype = np.int8)
array[:P] = 1
np.random.shuffle(array)# non si può riassegnarlo
matrix = array.reshape(SIZE) # da 1d lo faccio diventare matrice
# Out:
# 5.8 μs ± 403 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %%
# %%timeit #per calcolare quanto ci mette
SIZE = (4, 6)
P = 5
array = np.zeros(SIZE[0] * SIZE[1], dtype = np.int8)
indici = np.random.choice(np.arange(0, SIZE[0] * SIZE[1]), P, replace = False)
array[indici] = 1
matrix = array.reshape(SIZE)
matrix
# Out:
# 28.8 μs ± 3.08 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)
